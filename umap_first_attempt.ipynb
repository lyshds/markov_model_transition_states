# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
import umap

# %%
#import umap.umap_ as umap

# %%
#import torch

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
penguins = pd.read_csv("https://github.com/allisonhorst/palmerpenguins/raw/5b5891f01b52ae26ad8cb9755ec93672f49328a8/data/penguins_size.csv")
penguins.head()
# Out:
#   species_short     island  culmen_length_mm  culmen_depth_mm  \
# 0        Adelie  Torgersen              39.1             18.7
# 1        Adelie  Torgersen              39.5             17.4
# 2        Adelie  Torgersen              40.3             18.0
# 3        Adelie  Torgersen               NaN              NaN
# 4        Adelie  Torgersen              36.7             19.3
#
#    flipper_length_mm  body_mass_g     sex
# 0              181.0       3750.0    MALE
# 1              186.0       3800.0  FEMALE
# 2              195.0       3250.0  FEMALE
# 3                NaN          NaN     NaN
# 4              193.0       3450.0  FEMALE

# %%
penguins = penguins.dropna()
penguins.species_short.value_counts()
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species_short, dtype: int64

# %%
sns.pairplot(penguins, hue='species_short')

# %%
reducer = umap.UMAP()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-670e0ad4d6f6> in <module>()
# ----> 1 reducer = umap.UMAP()
#
# AttributeError: module 'umap' has no attribute 'UMAP'

# %%
penguin_data = penguins[
    [
        "culmen_length_mm",
        "culmen_depth_mm",
        "flipper_length_mm",
        "body_mass_g",
    ]
].values
scaled_penguin_data = StandardScaler().fit_transform(penguin_data)

# %%
embedding = reducer.fit_transform(scaled_penguin_data)
embedding.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-18-7316cdb09f84> in <module>()
# ----> 1 embedding = reducer.fit_transform(scaled_penguin_data)
#       2 embedding.shape
#
# NameError: name 'reducer' is not defined

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=digits.target, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
plt.title('UMAP projection of the Digits dataset', fontsize=24);
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-9095c5bf004e> in <module>()
# ----> 1 plt.scatter(embedding[:, 0], embedding[:, 1], c=digits.target, cmap='Spectral', s=5)
#       2 plt.gca().set_aspect('equal', 'datalim')
#       3 plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
#       4 plt.title('UMAP projection of the Digits dataset', fontsize=24);
#
# NameError: name 'plt' is not defined

# %%
### new df sorted, fitlered etc... for individual flies 
### embed each muscle etc...
### choose certain muscles and flies 
### concatenate flies 
### replot DFs
